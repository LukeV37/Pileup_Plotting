# %%
import uproot
import awkward as ak
import numpy as np
import pickle

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
with uproot.open("/home/lvaughan/Pileup/Pileup_Project/pythia/output/dataset_diHiggs_mu200_NumEvents20k_MinJetpT80.root:fastjet") as f:
    jet_label = f["jet_true_Efrac"].array()
    jet_corrJVF = f["jet_corrJVF"].array()
    jet_RpT = f["jet_RpT"].array()
    jet_pt = f["jet_pt"].array()
    jet_eta = f["jet_eta"].array()
    jet_phi = f["jet_phi"].array()
    jet_m = f["jet_m"].array()

# %%
JVT_label = np.array(ak.ravel(jet_label))
JVT_corrJVF = np.array(ak.ravel(jet_corrJVF))
JVT_RpT = np.array(ak.ravel(jet_RpT))
# Out:
# /tmp/ipykernel_25031/2077757278.py:1: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   JVT_label = np.array(ak.ravel(jet_label))
# /tmp/ipykernel_25031/2077757278.py:2: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   JVT_corrJVF = np.array(ak.ravel(jet_corrJVF))
# /tmp/ipykernel_25031/2077757278.py:3: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   JVT_RpT = np.array(ak.ravel(jet_RpT))

# %%
threshold = 0.3

# %%
sig = (JVT_label > threshold)
bkg = ~sig

plt.title("Jet Truth Pileup Fraction")
plt.hist(JVT_label[sig],histtype='step',bins=int(100*(1-threshold)),label='HS Jets',color='r')
plt.hist(JVT_label[bkg],histtype='step',bins=int(100*(threshold)),label='PU Jets',color='b')

plt.axvline(x = threshold, color = 'k', label = 'PU Jet Cut',linestyle='dashed')
plt.xlabel("pufr",loc='right')
plt.legend()
plt.yscale('log')
plt.show()

plt.title("Jet corrJVF")
plt.hist(JVT_corrJVF[sig],bins=100,histtype='step',label='HS',density=True,color='r')
plt.hist(JVT_corrJVF[bkg],bins=100,histtype='step',label='PU',density=True,color='b')
plt.xlabel("corrJVF",loc='right')
plt.legend()
plt.yscale('log')
plt.show()

plt.title("Jet RpT")
plt.hist(JVT_RpT[sig],bins=100,histtype='step',label='HS',density=True,color='r')
plt.hist(JVT_RpT[bkg],bins=100,histtype='step',label='PU',density=True,color='b')
plt.xlabel("RpT",loc='right')
plt.legend()
plt.yscale('log')
plt.show()

# %%
sig = (JVT_label > threshold)
bkg = ~sig

gamma_sig = 0.5
plt.title("HS Jet JVT Distribution")
plt.hist2d(JVT_corrJVF[sig],JVT_RpT[sig],bins=64,density=True,norm=mcolors.PowerNorm(gamma_sig))
plt.xlabel("corrJVF",loc='right')
plt.ylabel("RpT",loc='top')
#plt.colorbar()
plt.show()

gamma_bkg = 0.04
plt.title("PU Jet JVT Distribution")
plt.hist2d(JVT_corrJVF[bkg],JVT_RpT[bkg],bins=64,density=True,norm=mcolors.PowerNorm(gamma_bkg))
plt.xlabel("corrJVF",loc='right')
plt.ylabel("RpT",loc='top')
plt.show()

# %%
X = np.vstack((JVT_corrJVF,JVT_RpT)).T
y = (JVT_label > threshold).astype(float)

p = np.random.permutation(len(X))
X = X[p]
y = y[p]
JVT_label = JVT_label[p]
JVT_RpT = JVT_RpT[p]
JVT_corrJVF = JVT_corrJVF[p]

# Total 10k events
num_train = int(len(X) - 0.25*len(X))

X_train_JVT = X[0:num_train]
y_train_JVT = y[0:num_train]

X_test_JVT = X[num_train:]
y_test_JVT = y[num_train:]

kNN = KNeighborsClassifier(n_neighbors=100)

kNN.fit(X_train_JVT,y_train_JVT)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
x = np.linspace(0,1,100)
y = np.flip(np.linspace(0,1,100))

xv, yv = np.meshgrid(x,y, copy=True)

zv = np.zeros_like(xv)

for i in range(len(x)):
    for j in range(len(y)):
        zv[j,i] = kNN.predict_proba([[x[i],y[j]]])[:,1][0]

plt.title("JVT Score")
plt.imshow(zv, extent=[0, 1, 0, 1])

plt.xlabel("corrJVF")
plt.ylabel("RpT")
plt.colorbar()
plt.show()

y_pred = kNN.predict_proba(X_test_JVT)
plt.title("JVT Score")
plt.hist(y_pred[:,1][y_test_JVT==1],bins=18,histtype='step',label='HS',density=True,color='r')
plt.hist(y_pred[:,1][y_test_JVT==0],bins=18,histtype='step',label='PU',density=True,color='b')
plt.legend(loc='upper center')
plt.yscale('log')
plt.show()

# %%
Attn_label = ak.values_astype((jet_label > threshold), int)

num_feats = 6
mean_list = []
std_list = []
feat_list = [jet_corrJVF,jet_RpT,jet_pt,jet_eta,jet_phi,jet_m]
norm_list = []
for feat in feat_list:
    mean = ak.mean(feat)
    std = ak.std(feat)
    norm_list.append(((feat-mean)/std))    
    
feat_names = ["corrJVF","RpT","pT","eta","phi","m"]

plot=False
if plot:
    for i in range(num_feats):
        fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))

        ax1.set_title(feat_names[i])
        ax1.hist(ak.ravel(feat_list[i][Attn_label==1]),histtype='step',label='HS',density=True,bins=10)
        ax1.hist(ak.ravel(feat_list[i][Attn_label==0]),histtype='step',label='PU',density=True,bins=10)
        ax1.legend()

        ax2.set_title("Norm "+feat_names[i])
        ax2.hist(ak.ravel(norm_list[i][Attn_label==1]),histtype='step',label='HS',density=True,bins=10)
        ax2.hist(ak.ravel(norm_list[i][Attn_label==0]),histtype='step',label='PU',density=True,bins=10)
        ax2.legend()

        plt.show()

        print("Mean Before: ", ak.mean(feat_list[i]), "\t\t Mean After: ", ak.mean(norm_list[i]))
        print("STD Before: ", ak.std(feat_list[i]), "\t\t STD After: ", ak.std(norm_list[i]))

# %%
num_events = len(jet_pt)
train_split = int(0.7*num_events)
test_split = int(0.75*num_events)

batch = False
if batch:
    minibatch_size = 2
    num_minibatches = int(train_split/minibatch_size)

    X_train = []
    y_train = []
    for b in range(num_minibatches):
        batch_data = []
        for feat in norm_list:
            data = feat[b*minibatch_size:(b+1)*minibatch_size]
            max_num_jets = ak.max(ak.num(data,axis=1))
            data_padded = ak.pad_none(data,max_num_jets,axis=1)
            batch_data.append(ak.fill_none(data_padded,0.0,axis=1)[:,:,np.newaxis])

        label = Attn_label[b*minibatch_size:(b+1)*minibatch_size]
        label_padded = ak.pad_none(label,max_num_jets,axis=1)
        label_padded = ak.fill_none(label_padded,-1.0,axis=1)
        batch_labels= np.array(label_padded).reshape(minibatch_size,max_num_jets,1)

        feats = ak.concatenate(batch_data, axis=2)
        X_train.append(torch.Tensor(feats))
        y_train.append(torch.Tensor(batch_labels))

Norm_list = [x[:,:,np.newaxis] for x in norm_list]
jet_feats = ak.concatenate(Norm_list, axis=2)

if not batch:
    X_train = jet_feats[0:train_split]
    X_train = torch.nested.nested_tensor(ak.to_list(X_train), dtype=torch.float32)    
    y_train = Attn_label[0:train_split]
    y_train = torch.nested.nested_tensor(ak.to_list(y_train), dtype=torch.float32)
    
X_val = jet_feats[train_split:test_split]
X_val = torch.nested.nested_tensor(ak.to_list(X_val), dtype=torch.float32)
y_val = Attn_label[train_split:test_split]
y_val = torch.nested.nested_tensor(ak.to_list(y_val), dtype=torch.float32)

X_test = jet_feats[test_split:]
X_test = torch.nested.nested_tensor(ak.to_list(X_test), dtype=torch.float32)
y_test = Attn_label[test_split:]
y_test = torch.nested.nested_tensor(ak.to_list(y_test), dtype=torch.float32)
# Out:
# /home/lvaughan/VirtualEnvs/torch/lib/python3.10/site-packages/torch/nested/__init__.py:226: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at ../aten/src/ATen/NestedTensorImpl.cpp:178.)
#   return _nested.nested_tensor(

# %%
class Encoder(nn.Module):
    def __init__(self, embed_dim, num_heads):
        super(Encoder, self).__init__()
        self.attention = nn.MultiheadAttention(embed_dim,num_heads=num_heads,batch_first=True, dropout=0.25)
        self.out = nn.Linear(embed_dim,embed_dim)
    def forward(self, Query, Key, Value):
        context, weights = self.attention(Query, Key, Value)
        latent = Query + context
        tmp = F.gelu(self.out(latent))
        latent = latent + tmp
        return latent, weights

class AttnModel(nn.Module):
    def __init__(self, in_feats, embed_dim, num_heads, out_classes):
        super(AttnModel, self).__init__()        
        self.preprocess = nn.Linear(in_feats,embed_dim)

        self.encoder1 = Encoder(embed_dim, num_heads)
        self.encoder2 = Encoder(embed_dim, num_heads)
        self.encoder3 = Encoder(embed_dim, num_heads)
        self.encoder4 = Encoder(embed_dim, num_heads)
        
        self.classifier = nn.Linear(embed_dim,out_classes)
    def forward(self, jet_feats,return_weights=False):
        # Preprocess Jet Feats
        jet_embedding = F.gelu(self.preprocess(jet_feats))
        
        # Attention Encoder
        jet_embedding, jet_weights = self.encoder1(jet_embedding,jet_embedding,jet_embedding)
        #jet_embedding, jet_weights = self.encoder2(jet_embedding,jet_embedding,jet_embedding)
        #jet_embedding, jet_weights = self.encoder3(jet_embedding,jet_embedding,jet_embedding)
        #jet_embedding, jet_weights = self.encoder4(jet_embedding,jet_embedding,jet_embedding)

        # Classify
        output = F.sigmoid(self.classifier(jet_embedding))
        
        if return_weights:
            return output, jet_weights
        return output

# %%
class BaselineNN(nn.Module):
    def __init__(self, in_feats, hidden_feats, out_feats):
        super(BaselineNN, self).__init__()        
        self.jet_preprocess = nn.Linear(in_feats,hidden_feats)
        self.jet_classifier = nn.Linear(hidden_feats,out_feats)
    def forward(self, jet_feats):
        # Preprocess Jet Feats
        jet_embedding = F.gelu(self.jet_preprocess(jet_feats))

        # Classify
        output = F.sigmoid(self.jet_classifier(jet_embedding))
        return output

# %%
def train(model, data, epochs=20, batched=False):
    X_train, y_train, X_val, y_val = data
    
    history = {'train_loss':[],'val_loss':[]}
   
    for e in range(epochs):     
        cum_loss_train = []
        cum_loss_val = []
        if batched:
            num_train = len(X_train)
        else:
            num_train = X_train.size(0)
        model.train()
        for i in range(num_train):
            optimizer.zero_grad()
            output = model(X_train[i].to(device))
            if batched:
                mask = (y_train[i] != -1).float().to(device)
                loss = loss_fn(output*mask, y_train[i].to(device)*mask)
            else:
                loss = loss_fn(output, y_train[i].reshape(-1,1).to(device))
            loss.backward()
            optimizer.step()
            cum_loss_train.append(loss.detach().cpu().numpy())
        
        num_val = X_val.size(0)
        model.eval()
        for event in range(num_val):
            y_pred = model(X_val[event].to(device))
            loss = loss_fn(y_pred,y_val[event].reshape(-1,1).to(device))
            cum_loss_val.append(loss.detach().cpu().numpy())

        history['train_loss'].append(np.mean(cum_loss_train))
        history['val_loss'].append(np.mean(cum_loss_val))

        if (e+1)%1==0:
            print('Epoch:',e+1,'\tTrain Loss:',round(float(np.mean(cum_loss_train)),4),'\tVal Loss:',round(float(np.mean(cum_loss_val)),4))

    return history

# %%
print("GPU Available: ", torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# GPU Available:  True
# cuda:0

# %%
hidden_layer = 32
num_heads=8

model = AttnModel(6,hidden_layer,num_heads,1)
params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("Attention Model Trainable Params: ", params)

fudge_factor = 1
baseline = BaselineNN(6,int(params/num_heads*fudge_factor),1)
print("Baseline Model Trainable Params: ", sum(p.numel() for p in baseline.parameters() if p.requires_grad))
# Out:
# Attention Model Trainable Params:  21377
# Baseline Model Trainable Params:  21377

# %%
# Use BinaryCrossEntropy for binary classification
loss_fn = nn.BCELoss()

Epochs = 80

# Train baseline NN
print("Training BaselineNN")
baseline.to(device)
optimizer = optim.AdamW(baseline.parameters(), lr=0.0001)
data = [X_train, y_train, X_val, y_val]
if not batch:
    baseline_history = train(baseline, data, epochs=Epochs)
if batch:
    baseline_history = train(baseline, data, epochs=Epochs,batched=True)
print()


Epochs = 120

# Train Attention Model
print("Training AttnJVT")
model.to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0001)
data = [X_train, y_train, X_val, y_val]
if not batch:
    model_history = train(model, data, epochs=Epochs)
if batch:
    model_history = train(model, data, epochs=Epochs,batched=True)
print()
# Out:
# Training BaselineNN
# Epoch: 1 	Train Loss: 0.0218 	Val Loss: 0.0186
# Epoch: 2 	Train Loss: 0.0179 	Val Loss: 0.0183
# Epoch: 3 	Train Loss: 0.0178 	Val Loss: 0.0182
# Epoch: 4 	Train Loss: 0.0177 	Val Loss: 0.0182
# Epoch: 5 	Train Loss: 0.0177 	Val Loss: 0.0181
# Epoch: 6 	Train Loss: 0.0176 	Val Loss: 0.0181
# Epoch: 7 	Train Loss: 0.0176 	Val Loss: 0.018
# Epoch: 8 	Train Loss: 0.0176 	Val Loss: 0.018
# Epoch: 9 	Train Loss: 0.0176 	Val Loss: 0.018
# Epoch: 10 	Train Loss: 0.0176 	Val Loss: 0.018
# Epoch: 11 	Train Loss: 0.0175 	Val Loss: 0.018
# Epoch: 12 	Train Loss: 0.0175 	Val Loss: 0.018
# Epoch: 13 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 14 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 15 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 16 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 17 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 18 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 19 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 20 	Train Loss: 0.0175 	Val Loss: 0.0179
# Epoch: 21 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 22 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 23 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 24 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 25 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 26 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 27 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 28 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 29 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 30 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 31 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 32 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 33 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 34 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 35 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 36 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 37 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 38 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 39 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 40 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 41 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 42 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 43 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 44 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 45 	Train Loss: 0.0174 	Val Loss: 0.0179
# Epoch: 46 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 47 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 48 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 49 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 50 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 51 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 52 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 53 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 54 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 55 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 56 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 57 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 58 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 59 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 60 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 61 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 62 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 63 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 64 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 65 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 66 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 67 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 68 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 69 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 70 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 71 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 72 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 73 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 74 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 75 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 76 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 77 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 78 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 79 	Train Loss: 0.0174 	Val Loss: 0.0178
# Epoch: 80 	Train Loss: 0.0174 	Val Loss: 0.0178
#
# Training AttnJVT
# Epoch: 1 	Train Loss: 0.03 	Val Loss: 0.0183
# Epoch: 2 	Train Loss: 0.0175 	Val Loss: 0.0178
# Epoch: 3 	Train Loss: 0.0171 	Val Loss: 0.0176
# Epoch: 4 	Train Loss: 0.0169 	Val Loss: 0.0174
# Epoch: 5 	Train Loss: 0.0167 	Val Loss: 0.0172
# Epoch: 6 	Train Loss: 0.0166 	Val Loss: 0.0171
# Epoch: 7 	Train Loss: 0.0165 	Val Loss: 0.0169
# Epoch: 8 	Train Loss: 0.0164 	Val Loss: 0.0168
# Epoch: 9 	Train Loss: 0.0164 	Val Loss: 0.0167
# Epoch: 10 	Train Loss: 0.0163 	Val Loss: 0.0166
# Epoch: 11 	Train Loss: 0.0162 	Val Loss: 0.0166
# Epoch: 12 	Train Loss: 0.0162 	Val Loss: 0.0165
# Epoch: 13 	Train Loss: 0.0162 	Val Loss: 0.0164
# Epoch: 14 	Train Loss: 0.0161 	Val Loss: 0.0163
# Epoch: 15 	Train Loss: 0.0161 	Val Loss: 0.0163
# Epoch: 16 	Train Loss: 0.016 	Val Loss: 0.0162
# Epoch: 17 	Train Loss: 0.0161 	Val Loss: 0.0162
# Epoch: 18 	Train Loss: 0.016 	Val Loss: 0.0161
# Epoch: 19 	Train Loss: 0.0159 	Val Loss: 0.0161
# Epoch: 20 	Train Loss: 0.0159 	Val Loss: 0.016
# Epoch: 21 	Train Loss: 0.0159 	Val Loss: 0.016
# Epoch: 22 	Train Loss: 0.0158 	Val Loss: 0.0159
# Epoch: 23 	Train Loss: 0.0158 	Val Loss: 0.0159
# Epoch: 24 	Train Loss: 0.0158 	Val Loss: 0.0158
# Epoch: 25 	Train Loss: 0.0158 	Val Loss: 0.0158
# Epoch: 26 	Train Loss: 0.0157 	Val Loss: 0.0158
# Epoch: 27 	Train Loss: 0.0157 	Val Loss: 0.0157
# Epoch: 28 	Train Loss: 0.0156 	Val Loss: 0.0156
# Epoch: 29 	Train Loss: 0.0156 	Val Loss: 0.0156
# Epoch: 30 	Train Loss: 0.0155 	Val Loss: 0.0155
# Epoch: 31 	Train Loss: 0.0155 	Val Loss: 0.0155
# Epoch: 32 	Train Loss: 0.0155 	Val Loss: 0.0154
# Epoch: 33 	Train Loss: 0.0154 	Val Loss: 0.0154
# Epoch: 34 	Train Loss: 0.0154 	Val Loss: 0.0153
# Epoch: 35 	Train Loss: 0.0154 	Val Loss: 0.0153
# Epoch: 36 	Train Loss: 0.0153 	Val Loss: 0.0152
# Epoch: 37 	Train Loss: 0.0153 	Val Loss: 0.0151
# Epoch: 38 	Train Loss: 0.0152 	Val Loss: 0.0151
# Epoch: 39 	Train Loss: 0.0152 	Val Loss: 0.015
# Epoch: 40 	Train Loss: 0.0151 	Val Loss: 0.015
# Epoch: 41 	Train Loss: 0.0151 	Val Loss: 0.0149
# Epoch: 42 	Train Loss: 0.015 	Val Loss: 0.0148
# Epoch: 43 	Train Loss: 0.015 	Val Loss: 0.0148
# Epoch: 44 	Train Loss: 0.0149 	Val Loss: 0.0148
# Epoch: 45 	Train Loss: 0.015 	Val Loss: 0.0147
# Epoch: 46 	Train Loss: 0.0149 	Val Loss: 0.0146
# Epoch: 47 	Train Loss: 0.0148 	Val Loss: 0.0146
# Epoch: 48 	Train Loss: 0.0148 	Val Loss: 0.0145
# Epoch: 49 	Train Loss: 0.0147 	Val Loss: 0.0145
# Epoch: 50 	Train Loss: 0.0147 	Val Loss: 0.0144
# Epoch: 51 	Train Loss: 0.0147 	Val Loss: 0.0145
# Epoch: 52 	Train Loss: 0.0146 	Val Loss: 0.0144
# Epoch: 53 	Train Loss: 0.0146 	Val Loss: 0.0144
# Epoch: 54 	Train Loss: 0.0146 	Val Loss: 0.0144
# Epoch: 55 	Train Loss: 0.0145 	Val Loss: 0.0143
# Epoch: 56 	Train Loss: 0.0145 	Val Loss: 0.0142
# Epoch: 57 	Train Loss: 0.0145 	Val Loss: 0.0144
# Epoch: 58 	Train Loss: 0.0144 	Val Loss: 0.0141
# Epoch: 59 	Train Loss: 0.0144 	Val Loss: 0.0141
# Epoch: 60 	Train Loss: 0.0144 	Val Loss: 0.0141
# Epoch: 61 	Train Loss: 0.0144 	Val Loss: 0.014
# Epoch: 62 	Train Loss: 0.0143 	Val Loss: 0.014
# Epoch: 63 	Train Loss: 0.0143 	Val Loss: 0.0141
# Epoch: 64 	Train Loss: 0.0143 	Val Loss: 0.014
# Epoch: 65 	Train Loss: 0.0142 	Val Loss: 0.014
# Epoch: 66 	Train Loss: 0.0143 	Val Loss: 0.0139
# Epoch: 67 	Train Loss: 0.0143 	Val Loss: 0.0139
# Epoch: 68 	Train Loss: 0.0143 	Val Loss: 0.0139
# Epoch: 69 	Train Loss: 0.0142 	Val Loss: 0.0139
# Epoch: 70 	Train Loss: 0.0141 	Val Loss: 0.0139
# Epoch: 71 	Train Loss: 0.0142 	Val Loss: 0.014
# Epoch: 72 	Train Loss: 0.0141 	Val Loss: 0.0139
# Epoch: 73 	Train Loss: 0.014 	Val Loss: 0.0139
# Epoch: 74 	Train Loss: 0.0142 	Val Loss: 0.0137
# Epoch: 75 	Train Loss: 0.0141 	Val Loss: 0.0137
# Epoch: 76 	Train Loss: 0.0141 	Val Loss: 0.0137
# Epoch: 77 	Train Loss: 0.0141 	Val Loss: 0.0137
# Epoch: 78 	Train Loss: 0.014 	Val Loss: 0.0137
# Epoch: 79 	Train Loss: 0.014 	Val Loss: 0.0137
# Epoch: 80 	Train Loss: 0.0141 	Val Loss: 0.0137
# Epoch: 81 	Train Loss: 0.014 	Val Loss: 0.0136
# Epoch: 82 	Train Loss: 0.0139 	Val Loss: 0.0136
# Epoch: 83 	Train Loss: 0.014 	Val Loss: 0.0137
# Epoch: 84 	Train Loss: 0.014 	Val Loss: 0.0136
# Epoch: 85 	Train Loss: 0.014 	Val Loss: 0.0135
# Epoch: 86 	Train Loss: 0.014 	Val Loss: 0.0136
# Epoch: 87 	Train Loss: 0.014 	Val Loss: 0.0137
# Epoch: 88 	Train Loss: 0.0139 	Val Loss: 0.0136
# Epoch: 89 	Train Loss: 0.0139 	Val Loss: 0.0136
# Epoch: 90 	Train Loss: 0.0139 	Val Loss: 0.0136
# Epoch: 91 	Train Loss: 0.0139 	Val Loss: 0.0135
# Epoch: 92 	Train Loss: 0.0138 	Val Loss: 0.0135
# Epoch: 93 	Train Loss: 0.0139 	Val Loss: 0.0136
# Epoch: 94 	Train Loss: 0.0139 	Val Loss: 0.0135
# Epoch: 95 	Train Loss: 0.0139 	Val Loss: 0.0135
# Epoch: 96 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 97 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 98 	Train Loss: 0.0138 	Val Loss: 0.0136
# Epoch: 99 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 100 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 101 	Train Loss: 0.0138 	Val Loss: 0.0135
# Epoch: 102 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 103 	Train Loss: 0.0138 	Val Loss: 0.0135
# Epoch: 104 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 105 	Train Loss: 0.0138 	Val Loss: 0.0133
# Epoch: 106 	Train Loss: 0.0138 	Val Loss: 0.0134
# Epoch: 107 	Train Loss: 0.0138 	Val Loss: 0.0133
# Epoch: 108 	Train Loss: 0.0137 	Val Loss: 0.0133
# Epoch: 109 	Train Loss: 0.0138 	Val Loss: 0.0132
# Epoch: 110 	Train Loss: 0.0137 	Val Loss: 0.0133
# Epoch: 111 	Train Loss: 0.0137 	Val Loss: 0.0133
# Epoch: 112 	Train Loss: 0.0137 	Val Loss: 0.0135
# Epoch: 113 	Train Loss: 0.0137 	Val Loss: 0.0133
# Epoch: 114 	Train Loss: 0.0137 	Val Loss: 0.0134
# Epoch: 115 	Train Loss: 0.0137 	Val Loss: 0.0134
# Epoch: 116 	Train Loss: 0.0137 	Val Loss: 0.0132
# Epoch: 117 	Train Loss: 0.0137 	Val Loss: 0.0132
# Epoch: 118 	Train Loss: 0.0137 	Val Loss: 0.0133
# Epoch: 119 	Train Loss: 0.0136 	Val Loss: 0.0132
# Epoch: 120 	Train Loss: 0.0136 	Val Loss: 0.0133

# %%
plt.plot(baseline_history['train_loss'][1:],label='train')
plt.plot(baseline_history['val_loss'][1:],label='validation')
plt.title("BaselineNN Loss")
plt.legend()
plt.yscale('log')
plt.show()

plt.plot(model_history['train_loss'][1:],label='train')
plt.plot(model_history['val_loss'][1:],label='validation')
plt.title("AttnJVT Loss")
plt.legend()
plt.yscale('log')
plt.show()

# %%
def roc(y_true, y_pred):
    sig = (y_true==1)
    bkg = ~sig
    
    sig_eff = []
    fake_rate = []
    
    thresholds = np.linspace(0,0.97,100)
    
    for threshold in thresholds:
        sig_eff.append(((y_pred[sig] > threshold).sum() / y_true[sig].shape[0]))
        fake_rate.append(((y_pred[bkg] > threshold).sum()  / y_true[bkg].shape[0]))
        
    return np.array(sig_eff), np.array(fake_rate), thresholds

y_pred_JVT = kNN.predict_proba(X_test_JVT)[:,1]

baseline.to(device)
model.to(device)

y_pred_baseline = []
y_pred_attn = []
weights = []
y_Test = []
for event in range(X_test.size(0)):
    y_pred_baseline.append(baseline(X_test[event].to(device)).detach().cpu().numpy())
    output, weight =model(X_test[event].to(device),return_weights=True)
    y_pred_attn.append(output.detach().cpu().numpy())
    weights.append(weight.detach().cpu().numpy())
    y_Test.append(y_test[event].detach().numpy())
    
y_pred_baseline = np.array(ak.ravel(y_pred_baseline))
y_pred_attn = np.array(ak.ravel(y_pred_attn))
y_Test = np.array(ak.ravel(y_Test))

x1,y1,th1 = roc(y_test_JVT,y_pred_JVT)
x2,y2,th2 = roc(y_Test,y_pred_baseline)
x3,y3,th3 = roc(y_Test,y_pred_attn)

plt.title("JVT ROC Curve")
plt.plot(x1,y1,color='b',label='JVT')
plt.plot(x2,y2,color='r',label='BaselineNN')
plt.plot(x3,y3,color='g',label='AttnJVT')

plt.ylabel('Fake Rate',loc='top')
plt.xlabel('Signal Efficiency',loc='right')
plt.yscale('log')
plt.legend(loc='upper left')
plt.xlim([0.8, 1])
plt.grid(which='both')
plt.show()
print("JVT Binary Accuracy: \t\t\t", accuracy_score(y_test_JVT, y_pred_JVT>threshold))
print("BaselineNN Binary Accuracy: \t\t", accuracy_score(y_Test, y_pred_baseline>threshold))
print("Attention Model Binary Accuracy: \t", accuracy_score(y_Test, y_pred_attn>threshold))
# Out:
# /tmp/ipykernel_25031/1111865897.py:32: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   y_pred_baseline = np.array(ak.ravel(y_pred_baseline))
# /tmp/ipykernel_25031/1111865897.py:33: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   y_pred_attn = np.array(ak.ravel(y_pred_attn))
# /tmp/ipykernel_25031/1111865897.py:34: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   y_Test = np.array(ak.ravel(y_Test))
# JVT Binary Accuracy: 			 0.9886702261338749
# BaselineNN Binary Accuracy: 		 0.991868434718673
# Attention Model Binary Accuracy: 	 0.9944367033611156

# %%
torch.save(baseline, "BaselineNN_mu200.torch")
torch.save(model, "AttnJVT_mu200.torch")
with open('JVT_mu200.pkl', 'wb') as f:
    pickle.dump(kNN, f)
